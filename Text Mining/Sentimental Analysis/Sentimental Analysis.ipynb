# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix
from sklearn.svm import SVC
import re

# %%
# Load training dataset
df= pd.read_csv("gold-dataset-sinha-khandait.csv")
df
# Out:
#             Dates                                                URL  \
# 0      28-01-2016  http://www.marketwatch.com/story/april-gold-do...
# 1      13-09-2017  http://www.marketwatch.com/story/gold-prices-s...
# 2      26-07-2016  http://www.marketwatch.com/story/gold-futures-...
# 3      28-02-2018  https://www.metalsdaily.com/link/277199/dent-r...
# 4      06-09-2017  http://www.marketwatch.com/story/gold-steadies...
# ...           ...                                                ...
# 11407  07-01-2013  https://www.moneycontrol.com/news/business/mar...
# 11408  27-09-2018  https://www.metalsdaily.com/link/284468/domini...
# 11409  03-03-2017  https://www.thehindubusinessline.com/markets/g...
# 11410  11-06-2008  http://www.marketwatch.com/story/august-gold-u...
# 11411  01-10-2007  http://www.marketwatch.com/story/december-gold...
#
#                                                     News  Price Direction Up  \
# 0      april gold down 20 cents to settle at $1,116.1...                   0
# 1              gold suffers third straight daily decline                   0
# 2         Gold futures edge up after two-session decline                   1
# 3      dent research : is gold's day in the sun comin...                   0
# 4      Gold snaps three-day rally as Trump, lawmakers...                   0
# ...                                                  ...                 ...
# 11407       gold seen falling from 3-week high this week                   0
# 11408  dominic frisby : now looks like a good time to...                   0
# 11409  Gold heading for worst week since November on ...                   0
# 11410  august gold up $7.60 at $878.80 an ounce on nymex                   1
# 11411    december gold down $1 at $749 an ounce on nymex                   0
#
#        Price Direction Constant  Price Direction Down  Asset Comparision  \
# 0                             0                     1                  0
# 1                             0                     1                  0
# 2                             0                     0                  0
# 3                             0                     0                  0
# 4                             0                     1                  0
# ...                         ...                   ...                ...
# 11407                         0                     1                  0
# 11408                         0                     0                  0
# 11409                         0                     1                  0
# 11410                         0                     0                  0
# 11411                         0                     1                  0
#
#        Past Information  Future Information Price Sentiment
# 0                     1                   0        negative
# 1                     1                   0        negative
# 2                     1                   0        positive
# 3                     0                   1            none
# 4                     1                   0        negative
# ...                 ...                 ...             ...
# 11407                 1                   0        negative
# 11408                 0                   1            none
# 11409                 1                   0        negative
# 11410                 1                   0        positive
# 11411                 1                   0        negative
#
# [11412 rows x 10 columns]

# %%
# The Price Sentiment column contains 4 classes (positive, neutral, negative and none)
# Positive denotes upward movement in price
# Negative denotes downward movement in price
# Neutral denotes sideways (steady) movement in price
# None denotes that no assessment about prices can be made from the news headline

# %%
df = df[df["Price Sentiment"] != 'none']
df
# Out:
#             Dates                                                URL  \
# 0      28-01-2016  http://www.marketwatch.com/story/april-gold-do...
# 1      13-09-2017  http://www.marketwatch.com/story/gold-prices-s...
# 2      26-07-2016  http://www.marketwatch.com/story/gold-futures-...
# 4      06-09-2017  http://www.marketwatch.com/story/gold-steadies...
# 5      16-08-2016  http://www.marketwatch.com/story/dec-gold-clim...
# ...           ...                                                ...
# 11406  23-12-2016  http://www.marketwatch.com/story/february-gold...
# 11407  07-01-2013  https://www.moneycontrol.com/news/business/mar...
# 11409  03-03-2017  https://www.thehindubusinessline.com/markets/g...
# 11410  11-06-2008  http://www.marketwatch.com/story/august-gold-u...
# 11411  01-10-2007  http://www.marketwatch.com/story/december-gold...
#
#                                                     News  Price Direction Up  \
# 0      april gold down 20 cents to settle at $1,116.1...                   0
# 1              gold suffers third straight daily decline                   0
# 2         Gold futures edge up after two-session decline                   1
# 4      Gold snaps three-day rally as Trump, lawmakers...                   0
# 5      Dec. gold climbs $9.40, or 0.7%, to settle at ...                   1
# ...                                                  ...                 ...
# 11406  February gold up $3.70, or 0.3%, at $1,134.40/oz.                   1
# 11407       gold seen falling from 3-week high this week                   0
# 11409  Gold heading for worst week since November on ...                   0
# 11410  august gold up $7.60 at $878.80 an ounce on nymex                   1
# 11411    december gold down $1 at $749 an ounce on nymex                   0
#
#        Price Direction Constant  Price Direction Down  Asset Comparision  \
# 0                             0                     1                  0
# 1                             0                     1                  0
# 2                             0                     0                  0
# 4                             0                     1                  0
# 5                             0                     0                  0
# ...                         ...                   ...                ...
# 11406                         0                     0                  0
# 11407                         0                     1                  0
# 11409                         0                     1                  0
# 11410                         0                     0                  0
# 11411                         0                     1                  0
#
#        Past Information  Future Information Price Sentiment
# 0                     1                   0        negative
# 1                     1                   0        negative
# 2                     1                   0        positive
# 4                     1                   0        negative
# 5                     1                   0        positive
# ...                 ...                 ...             ...
# 11406                 1                   0        positive
# 11407                 1                   0        negative
# 11409                 1                   0        negative
# 11410                 1                   0        positive
# 11411                 1                   0        negative
#
# [9345 rows x 10 columns]

# %%
# headlines cleaner
def cleaner(impure_data):
    temp_list = []
    for item in impure_data:
        #finding words which start with @
        item = re.sub('@\S+', '', item)
        
        #finding words which start with http
        item = re.sub('http\S+\s*', '', item)
        
        #finding special characters, but not "emoji"
        item = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), '', item)
        temp_list.append(item)
    return temp_list

# %%
# a simple SVM model with tfidf vectorizer
def headline_sentiment(df):
    headlines = df["News"]
    polarity = df["Price Sentiment"].tolist()
    
    #cleaning headlines i.e. removing @mentions, http(s) links and special characters such as punctuations
    clean_headline = cleaner(headlines)
    
    #initializing tf-idf vectorizer
    tf_idfvectorizer = TfidfVectorizer(sublinear_tf=True, use_idf=True)
    
    #splitting the data into train and test dataset in 70 : 30 ratio at random
    X_train, X_test, Y_train, Y_test = train_test_split(clean_headline, polarity, test_size = 0.3)
    
    train_corpus_tf_idf = tf_idfvectorizer.fit_transform(X_train) 
    test_corpus_tf_idf = tf_idfvectorizer.transform(X_test)
    
    #using SVC package to initialize a classifier with Linear kernel and other default parameters
    SVM_L = SVC(kernel= 'linear')
    
    #fitting the sparse matrix in the classifier with their respective sentiments
    SVM_L.fit(train_corpus_tf_idf, Y_train)
    
    #predicting the sentiments for the test dataset
    Y_pred = SVM_L.predict(test_corpus_tf_idf)
    
    #this prints accuracy score for the test dataset
    print("Testing Accuracy:",accuracy_score(Y_test,Y_pred))
    
    #this prints confusion matrix for the test dataset
    labels = np.unique(Y_test)    
    m = confusion_matrix(Y_test,Y_pred, labels=labels)
    print("\nConfusion matrix on test data")
    cm = pd.DataFrame(m, index=labels, columns=labels)
    cm.index = "Actual: " + cm.index
    cm.columns = "Predicted: " + cm.columns
    display(cm)
    
    #saving the data into a csv file in the current folder
    temp_df = pd.DataFrame()
    temp_df["News"] = X_test
    temp_df["Actual Price Sentiment"] = Y_test
    temp_df["Predicted Sentiment"] = Y_pred
    temp_df.to_csv("predicted.csv")
    
    print('Predictions on Test Data are as follows:')
    display(temp_df)

    return(tf_idfvectorizer,SVM_L)

# %%
vectorizer,model = headline_sentiment(df)
# Out:
# Testing Accuracy: 0.9226105563480742
#
# Confusion matrix on test data
#                   Predicted: negative  Predicted: neutral  Predicted: positive
# Actual: negative                 1120                   8                   88
# Actual: neutral                    21                  84                   26
# Actual: positive                   66                   8                 1383
# Predictions on Test Data are as follows:
#                                                    News  \
# 0             Gold steady investors await cues from Fed
# 1     Gold Prices Slip for Two Consecutive Days on S...
# 2              gold ends up 08 platinum palladium rally
# 3             Gold drops on upbeat US data Fed language
# 4                    gold futures at fresh twoweek high
# ...                                                 ...
# 2799  gold silver futures continue lower in afternoo...
# 2800  gains for gold futures intensify as us dollar ...
# 2801    august gold trades at 90070oz up 920 or 1 in ny
# 2802  april gold climbs 4 to 65550oz in morning trading
# 2803  dec gold falls 40 cents to 64650oz in morning ...
#
#      Actual Price Sentiment Predicted Sentiment
# 0                   neutral             neutral
# 1                  negative            negative
# 2                  positive            positive
# 3                  negative            negative
# 4                  positive            positive
# ...                     ...                 ...
# 2799               negative            negative
# 2800               positive            negative
# 2801               positive            positive
# 2802               positive            positive
# 2803               negative            negative
#
# [2804 rows x 3 columns]

# %%
#Trying sample headlines
vector = vectorizer.transform(["Gold expected to beat expectations."])
sentiment = model.predict(vector)
print(sentiment)
# Out:
# ['positive']

# %%
#Load data
data=pd.read_json("scraped_articles.json")
data
# Out:
#                                                            newspapers
# Google_news_Chile   {'rss': 'https://news.google.com/rss/search?q=...
# Google_news_Norway  {'rss': 'https://news.google.com/rss/search?q=...
# Google_news_Peru    {'rss': 'https://news.google.com/rss/search?q=...

# %%
articles=[pd.DataFrame(data['newspapers']['Google_news_Chile']['articles']),
pd.DataFrame(data['newspapers']['Google_news_Norway']['articles']),
pd.DataFrame(data['newspapers']['Google_news_Peru']['articles'])]
news=pd.concat(articles,ignore_index=True)
news
# Out:
#                                                  link            published  \
# 0   https://www.digitaljournal.com/pr/fish-oil-mar...  2022-08-15T11:07:03
# 1   https://www.einnews.com/pr_news/583589445/fish...  2022-07-29T11:33:00
# 2   https://www.signatureluxurytravel.com.au/best-...  2022-08-15T09:37:30
# 3   https://www.washingtonpost.com/food/2022/07/25...  2022-07-25T08:00:00
# 4   https://www.oregonlive.com/travel/2022/07/the-...  2022-07-22T08:00:00
# 5   https://www.bakersfield.com/entertainment/food...  2022-08-05T08:00:00
# 6   https://www.perthnow.com.au/lifestyle/heres-wh...  2022-08-03T08:00:00
# 7   https://www.salon.com/2022/07/17/a-cheesy-omel...  2022-07-17T08:00:00
# 8   https://www.seafoodsource.com/news/supply-trad...  2022-07-27T20:14:07
# 9   https://www.naturalhistorymag.com/features/013...  2022-08-01T17:38:07
# 10  https://www.intrafish.com/feed/rabobank-fishme...  2022-07-18T08:00:00
# 11       https://therevelator.org/farmed-salmon-book/  2022-07-18T08:00:00
# 20  Rabobank: Fishmeal market finely balanced amid...
# 21  At this northern Illinois party, breath mints ...
# 22                          Dr. Giulio Pontecorvo, 98
# 23        We are currently unavailable in your region
# 24  What to eat (and how much it will cost) at the...
# 25  Bon Appétit: The World’s 50 Best Restaurants a...
# 26  16 vibrant recipes that ring the changes on pa...
# 27       We need to rethink our obsession with salmon
# 28                   3 Reasons to Avoid Farmed Salmon
# 29                      Cilantro Lime Dressing Recipe
# 30             The tomato’s unique rise to popularity
# 31  Score Discounts And Rewards At Over 15 Venues ...
# 32   Santa Monica Restaurant Holding Seafood Festival
# 33  Eat, Stay, Love: Check out 18 of our favorite ...
# 34  Inside the Most Exciting New Steakhouses in La...
# 35               The best restaurants in Saint Tropez
# 36             Key global shipping rates slip further
# 37  14 Essential Seafood Restaurants in San Francisco
#
#                                                  text
# 0   Fish Oil Market 2022 research provides accurat...
# 1   The global fish oil market is expected to exhi...
# 2   40. Schloss Schauenstein – Fürstenau\n\nSchlos...
# 3   Placeholder while article actions load\n\nWith...
# 4   Don’t look now, but The Gold Room is quickly b...
# 5   Thank you for reading!\n\nPlease log in, or si...
# 6   You’ve seen the Leeuwin Coast Akoya feature on...
# 7   This recipe is brought to you from the mystic ...
# 8   Peru closes north-central region anchovy seaso...
# 9   Features: July-August 2022\n\nSalmon The way t...
# 10  A higher than expected Peruvian anchovy quota ...
# 11  A new book looks at the “dark underbelly of ou...
# 12  Not so long ago, Atlantic salmon was an abunda...
# 13  Vessels monitored and on-site investigations\n...
# 14  One way of staying out of the kitchen at meal ...
# 15  Peru closes north-central region anchovy seaso...
# 16  The harvesting of just over 84 percent of the ...
# 17  South American fishmeal producer Austral Group...
# 18  They may be one of the world’s favourite suppl...
# 19  A great many years ago, when I was young and i...
# 20  A higher than expected Peruvian anchovy quota ...
# 21  They say you can smell it from two blocks away...
# 22  Dr. Giulio Pontecorvo Jr. died on Sept. 26, 20...
# 23  Unfortunately, our website is currently unavai...
# 24  The first ingredient is patience. It takes tim...
# 25  40. Schloss Schauenstein – Fürstenau\n\nSchlos...
# 26  We're enjoying pesto made with everything from...
# 27  It’s the nation’s favourite fish. Last year we...
# 28  Not so long ago, Atlantic salmon was an abunda...
# 29  So you ate the Guacamole Greens salad at Sweet...
# 30  In the mornings during the summer, I like to w...
# 31  We acknowledge the Traditional Custodians of c...
# 32  Dia del Pescador comes to Socalo August 4-7\n\...
# 33  Eat, Stay, Love: Check out 18 of our favorite ...
# 34  In Las Vegas, one of the best weekend parties ...
# 35  Bello Visto\n\nDon’t bother to strut your summ...
# 36  Shipping rates on key routes from China to Eur...
# 37  Considering this city’s prime location between...

# %%
news['title'][0]
# Out:
# 'Fish Oil Market to Witness a Pronounce Growth during 2022-2028 by Top Key Players BASF SE, Camanchaca SA, China Fishery Group Limited, Copeinca ASA'

# %%
#Trying on our data
sentiment_list=[]
for item in news['title']:
    vector = vectorizer.transform([item])
    sentiment = model.predict(vector)
    sentiment_list.append(sentiment[0])
    print(item,sentiment)
# Out:
# Fish Oil Market to Witness a Pronounce Growth during 2022-2028 by Top Key Players BASF SE, Camanchaca SA, China Fishery Group Limited, Copeinca ASA ['positive']
# Fish Oil Market Size, Share, Growth, Analysis, Price, Trends and Forecast 2022-2027 ['positive']
# Bon Appétit: The World’s 50 Best Restaurants announced ['positive']
# Tom Sietsema’s 7 favorite places to eat right now ['negative']
# The Gold Room serves fresh pizza from a beautiful space in remote northeast Oregon ['positive']
# THE DISH: Pizza my heart: You must try these local pies ['positive']
# Here’s where to taste Akoya this winter ['positive']
# A cheesy omelet duvet with gochujang fried rice that oozes warmth and comfort ['negative']
# Peru closes north-central region anchovy season at just 84 percent of TAC ['positive']
# Natural History Magazine ['positive']
# Rabobank: Fishmeal market finely balanced amid reduced Chinese demand ['negative']
# Salmon Farming’s Dirty Business • The Revelator ['positive']
# 3 Reasons to Avoid Farmed Salmon ['positive']
# Energy audit and carbon footprint in trawl fisheries ['positive']
# Cold roasts are a hot weather treat ['positive']
# Peru closes north-central region anchovy season at just 84 percent of TAC ['positive']
# 'A fantastic result': Peru anchovy fleet wins praise for battling to finish line in tough first season ['negative']
# Austral Group invests $10 million in new Peru anchovy trawler ['negative']
# From the archive: what are the hidden costs of our obsession with fish oil pills? – podcast ['positive']
# In Praise Of Anchovies: If You Don’t Already Love Them, You Just Haven’t Yet Discovered How Good They Can Be ['positive']
# Rabobank: Fishmeal market finely balanced amid reduced Chinese demand ['negative']
# At this northern Illinois party, breath mints are provided ['positive']
# Dr. Giulio Pontecorvo, 98 ['positive']
# We are currently unavailable in your region ['positive']
# What to eat (and how much it will cost) at the world’s new top five restaurants ['positive']
# Bon Appétit: The World’s 50 Best Restaurants announced ['positive']
# 16 vibrant recipes that ring the changes on pasta + pesto ['positive']
# We need to rethink our obsession with salmon ['negative']
# 3 Reasons to Avoid Farmed Salmon ['positive']
# Cilantro Lime Dressing Recipe ['positive']
# The tomato’s unique rise to popularity ['positive']
# Score Discounts And Rewards At Over 15 Venues Around Town With This New App ['negative']
# Santa Monica Restaurant Holding Seafood Festival ['positive']
# Eat, Stay, Love: Check out 18 of our favorite Florida hotel restaurants ['positive']
# Inside the Most Exciting New Steakhouses in Las Vegas ['positive']
# The best restaurants in Saint Tropez ['positive']
# Key global shipping rates slip further ['negative']
# 14 Essential Seafood Restaurants in San Francisco ['negative']

# %%
sentiment_list
# Out:
# ['positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative']

# %%
news['Price Sentiment']=sentiment_list
news
# Out:
#                                                  link            published  \
# 0   https://www.digitaljournal.com/pr/fish-oil-mar...  2022-08-15T11:07:03
# 1   https://www.einnews.com/pr_news/583589445/fish...  2022-07-29T11:33:00
# 2   https://www.signatureluxurytravel.com.au/best-...  2022-08-15T09:37:30
# 3   https://www.washingtonpost.com/food/2022/07/25...  2022-07-25T08:00:00
# 4   https://www.oregonlive.com/travel/2022/07/the-...  2022-07-22T08:00:00
# 5   https://www.bakersfield.com/entertainment/food...  2022-08-05T08:00:00
# 6   https://www.perthnow.com.au/lifestyle/heres-wh...  2022-08-03T08:00:00
# 7   https://www.salon.com/2022/07/17/a-cheesy-omel...  2022-07-17T08:00:00
# 8   https://www.seafoodsource.com/news/supply-trad...  2022-07-27T20:14:07
# 16  'A fantastic result': Peru anchovy fleet wins ...
# 17  Austral Group invests $10 million in new Peru ...
# 18  From the archive: what are the hidden costs of...
# 19  In Praise Of Anchovies: If You Don’t Already L...
# 20  Rabobank: Fishmeal market finely balanced amid...
# 21  At this northern Illinois party, breath mints ...
# 22                          Dr. Giulio Pontecorvo, 98
# 23        We are currently unavailable in your region
# 24  What to eat (and how much it will cost) at the...
# 25  Bon Appétit: The World’s 50 Best Restaurants a...
# 26  16 vibrant recipes that ring the changes on pa...
# 27       We need to rethink our obsession with salmon
# 28                   3 Reasons to Avoid Farmed Salmon
# 29                      Cilantro Lime Dressing Recipe
# 30             The tomato’s unique rise to popularity
# 31  Score Discounts And Rewards At Over 15 Venues ...
# 32   Santa Monica Restaurant Holding Seafood Festival
# 33  Eat, Stay, Love: Check out 18 of our favorite ...
# 34  Inside the Most Exciting New Steakhouses in La...
# 35               The best restaurants in Saint Tropez
# 36             Key global shipping rates slip further
# 37  14 Essential Seafood Restaurants in San Francisco
#
#                                                  text Price Sentiment
# 0   Fish Oil Market 2022 research provides accurat...        positive
# 1   The global fish oil market is expected to exhi...        positive
# 2   40. Schloss Schauenstein – Fürstenau\n\nSchlos...        positive
# 3   Placeholder while article actions load\n\nWith...        negative
# 4   Don’t look now, but The Gold Room is quickly b...        positive
# 5   Thank you for reading!\n\nPlease log in, or si...        positive
# 6   You’ve seen the Leeuwin Coast Akoya feature on...        positive
# 7   This recipe is brought to you from the mystic ...        negative
# 8   Peru closes north-central region anchovy seaso...        positive
# 9   Features: July-August 2022\n\nSalmon The way t...        positive
# 10  A higher than expected Peruvian anchovy quota ...        negative
# 11  A new book looks at the “dark underbelly of ou...        positive
# 12  Not so long ago, Atlantic salmon was an abunda...        positive
# 13  Vessels monitored and on-site investigations\n...        positive
# 14  One way of staying out of the kitchen at meal ...        positive
# 15  Peru closes north-central region anchovy seaso...        positive
# 16  The harvesting of just over 84 percent of the ...        negative
# 17  South American fishmeal producer Austral Group...        negative
# 18  They may be one of the world’s favourite suppl...        positive
# 19  A great many years ago, when I was young and i...        positive
# 20  A higher than expected Peruvian anchovy quota ...        negative
# 21  They say you can smell it from two blocks away...        positive
# 22  Dr. Giulio Pontecorvo Jr. died on Sept. 26, 20...        positive
# 23  Unfortunately, our website is currently unavai...        positive
# 24  The first ingredient is patience. It takes tim...        positive
# 25  40. Schloss Schauenstein – Fürstenau\n\nSchlos...        positive
# 26  We're enjoying pesto made with everything from...        positive
# 27  It’s the nation’s favourite fish. Last year we...        negative
# 28  Not so long ago, Atlantic salmon was an abunda...        positive
# 29  So you ate the Guacamole Greens salad at Sweet...        positive
# 30  In the mornings during the summer, I like to w...        positive
# 31  We acknowledge the Traditional Custodians of c...        negative
# 32  Dia del Pescador comes to Socalo August 4-7\n\...        positive
# 33  Eat, Stay, Love: Check out 18 of our favorite ...        positive
# 34  In Las Vegas, one of the best weekend parties ...        positive
# 35  Bello Visto\n\nDon’t bother to strut your summ...        positive
# 36  Shipping rates on key routes from China to Eur...        negative
# 37  Considering this city’s prime location between...        negative
